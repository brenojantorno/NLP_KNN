# %%
import numpy as np
import pandas as pd
import os

# %%
path = os.getcwd() + "/atribuna/aTribuna_completo"
textDataFrame = pd.DataFrame({'Texts':[]})

# %%
x =  pd.DataFrame({"Texts":["breno"]})
textDataFrame =  pd.concat([x,textDataFrame], ignore_index=True)
textDataFrame.head()
# Out:
#    Texts
# 0  breno

# %%
def read_text(path, file_Name):
    with open(path,'r') as f:
        Build_DataFreame(f, file_Name)

# %%
def Build_DataFreame(file, file_Name):
    
    dfAux =
# Out:
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# ...

# %%
def GetClassifier(file_Name):

# %%
for file_Name in os.listdir(path):    
    #if file.endswith(".txt"):
        file_path = f"{path}\{file_Name}"
  
        # call read text file function
        read_text(file_path, file_Name)
# Out:
# .25082006pot.txt
# .txt
# 004062006at2.txt
# 0101022003at2.txt
# 0101032006at2.txt
# 0101052005at2.txt
# 0101052006at2.txt
# 0101062005at2.txt
# 0101062006at2.txt
# 0101062006sro.txt
# 0101072006at2.txt
# 0101082006at2.txt
# 0101102006at2.txt
# 0101112004at2.txt
# 0101112006at2.txt
# 0101122005at2.txt
# 01012004at2.txt
# 0102012004at2.txt
# 0102022003at2.txt
# 0102022006at2.txt
# 0102022006sro.txt
# 0102032006at2.txt
# 0102042006at2.txt
# 0102052005at2.txt
# 0102052006at2.txt
# 0102072006at2.txt
# 0102082005at2.txt
# 0102082006at2.txt
# 0102092006at2.txt
# 0102102006at2.txt
# 0102112006at2.txt
# 0102112006sro.txt
# 0103022003at2.txt
# 0103022003inf.txt
# 0103042006at2.txt
# 0103052006at2.txt
# 0103062006at2.txt
# 0103072006at2.txt
# 0103082005at2.txt
# 0103082006at2.txt
# 0103082006sro.txt
# 0103092006at2.txt
# 0103102006at2.txt
# 0104012004at2.txt
# 0104022003at2.txt
# 0104022006at2.txt
# 0104042006at2.txt
# 0104052005at2.txt
# 0104052006at2.txt
# 0104052006sro.txt
# ...
